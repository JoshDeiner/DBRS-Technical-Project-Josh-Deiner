# %%
import requests
import pandas as pd
import numpy as np
import csv
from datetime import datetime


#Defined necessary paths/documents ie data 

zipcode_file = '../../../downloads/Zips2010_90.xlsx'  # Using the 2010 Zip Code Data.
zip_files_df = pd.read_excel(zipcode_file)
city_data_file_read= pd.read_excel("../../../downloads/tocopycitydata.xlsx")
boroughs_array = pd.Series(['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND'])

# %%
## Order of Questions Addressed 

# 1) Borough's relationship to complaints

# 2) Zipcodes relations to complaints 

# 3 Development an index of overall complainers per borough

# %%
# main data frame variables 
main_data_dataframe = pd.DataFrame( # drop nas
     {"Unique Key":city_data_file_read["Unique Key"],
        "Created Date":city_data_file_read["Created Date"],
        "Closed Date":city_data_file_read["Closed Date"],
        "Complaint Type":city_data_file_read["Complaint Type"],
        "Zip" : city_data_file_read["Incident Zip"],
        "Status": city_data_file_read["Status"],
        "Borough":city_data_file_read["Borough"]
     }
)
zip_file_df = pd.DataFrame ({
    "Zip": zip_files_df["Incident Zips"],
    "Population": zip_files_df["Population"]
})

# %%
# helper variables

popular_complaints = pd.Series(main_data_dataframe.groupby('Complaint Type').size().sort_values(ascending=False))
top_ten_pop_complaints = pd.Series(popular_complaints[:10])
complaints_tops_names = top_ten_pop_complaints.keys()

# %%
# helper functions placed up top in case they need to be used besides points of primary need

#Defined necessary paths/documents ie data 


def zipcodes_population_obj(): # has of zip_code file
    obj= {}
    length = len(zip_files_df['Population'] -1)
    pops = zip_files_df['Population']
    zips = zip_files_df['Incident Zips']
    one_array = []
    second_array = []
    for pop_value in pops:
        one_array.append(pop_value)
    for zip_value in zips:
        second_array.append(zip_value)
    for x in range(len(one_array)-1):
        once = one_array[x]
        twice = second_array[x]
        obj[twice] = once
    return obj

def define_base_obj_to_use(): # sets obj to use for most popular complaints. includes zero
    starter_complaints_obj = {}
    for x in complaints_tops_names:
        starter_complaints_obj[x] = 0
    return starter_complaints_obj



def take_in_zip_code_spit_out_population(x): 
    return (zip_file_df['Zip'][x])


def new_group_boroughs_by_zips():

    borough_list = ["BROOKLYN", "QUEENS", "BRONX", "STATEN ISLAND", "MANHATTAN"]
    borough_zips = {
    "BROOKLYN" : [],
    "QUEENS": [],
    "BRONX": [],
    "STATEN ISLAND": [],
    "MANHATTAN": []
}
    
    for zipcode in bronxtable['Zip']: 
        (borough_zips['BRONX'].append(float(zipcode)))
    for zipcode in manhattan_table['Zip']:
        borough_zips['MANHATTAN'].append(float(zipcode))
    for zipcode in queens_table['Zip']:
        borough_zips['QUEENS'].append(float(zipcode))
    for zipcode in staten_island_table['Zip']:
        borough_zips['STATEN ISLAND'].append(float(zipcode))
    for zipcode in brooklyn_table['Zip']:
        print(zipcode)
        borough_zips['BROOKLYN'].append(float(zipcode))
    return(borough_zips)

# %%
# To clean the data, I defined a series of variables isolating both the zipcodes and boroughs most popular. 

### DataFrame Organized By ZipCode
first_zipcode_table = main_data_dataframe.loc[main_data_dataframe.Zip == float(11385)] #["Complaint Type"]
second_zipcode_table = main_data_dataframe.loc[main_data_dataframe.Zip == float(11209)] #["Complaint Type"]
third_zipcode_table = main_data_dataframe.loc[main_data_dataframe.Zip == float(11215)] #["Complaint Type"]
fourth_zipcode_table = main_data_dataframe.loc[main_data_dataframe.Zip == float(11216)] #["Complaint Type"]
fifth_zipcode_table = main_data_dataframe.loc[main_data_dataframe.Zip == float(10456)] #["Complaint Type"]
sixth_complainer_table = main_data_dataframe.loc[main_data_dataframe.Zip == float(10453)] #["Complaint Type"]
seventh_complainer_table = main_data_dataframe.loc[main_data_dataframe.Zip == float(11226)] #["Complaint Type"]
eighth_complainer_table = main_data_dataframe.loc[main_data_dataframe.Zip == float(11213)] #["Complaint Type"]
nine_complainer_table = main_data_dataframe.loc[main_data_dataframe.Zip == float(10467)] #["Complaint Type"]
ten_complainer_table = main_data_dataframe.loc[main_data_dataframe.Zip == float(10452)] #["Complaint Type"]


### Row Values of Complaint Types. made for convenience 
first_zip_complaints =  first_zipcode_table["Complaint Type"]
second_zip_complaints = second_zipcode_table["Complaint Type"]
third_zip_complaints = third_zipcode_table["Complaint Type"]
fourth_zip_complaints = fourth_zipcode_table["Complaint Type"]
fifth_zip_complaints = fifth_zipcode_table["Complaint Type"]
six_zip_complaints = sixth_complainer_table["Complaint Type"]
seventh_zip_complaints = seventh_complainer_table["Complaint Type"]
eigth_zip_complaints = eighth_complainer_table["Complaint Type"]
nine_zip_complaints = nine_complainer_table["Complaint Type"]
tenth_zip_complaints = ten_complainer_table["Complaint Type"]


### DataFrame Organized By Borough

bronxtable = main_data_dataframe.loc[main_data_dataframe.Borough == 'BRONX']
manhattan_table = main_data_dataframe.loc[main_data_dataframe.Borough == 'MANHATTAN']
queens_table = main_data_dataframe.loc[main_data_dataframe.Borough == 'QUEENS']
staten_island_table = main_data_dataframe.loc[main_data_dataframe.Borough == 'STATEN ISLAND']
brooklyn_table = main_data_dataframe.loc[main_data_dataframe.Borough == 'BROOKLYN']
bronx_complaints =  bronxtable["Complaint Type"]

### Row Values of Complaint Types. made for convenience 


manhattan_complaints = manhattan_table["Complaint Type"]
queens_complaints = queens_table["Complaint Type"]
SI_complaints = staten_island_table["Complaint Type"]
brooklyn_complaints = brooklyn_table["Complaint Type"]
bronx_complaints =  bronxtable["Complaint Type"]

# %%
### The Zip Codes belong to Borough without nan or duplicates

brooklyn_zips = pd.Series(new_group_boroughs_by_zips()['BROOKLYN']).unique()
manhattan_zips = pd.Series(new_group_boroughs_by_zips()['MANHATTAN']).unique()
queens_zips = pd.Series(new_group_boroughs_by_zips()['QUEENS']).unique()
si_zips = pd.Series(new_group_boroughs_by_zips()['STATEN ISLAND']).unique()
bronx_zips = pd.Series(new_group_boroughs_by_zips()['BRONX']).unique()

brooklyn_zipcodes_array = pd.Series(brooklyn_zips).dropna().unique()
queens_zipcodes_array = pd.Series(queens_zips).dropna().unique()
bronx_zipcodes_array = pd.Series(bronx_zips).dropna().unique()
manhattan_zipcodes_array = pd.Series(manhattan_zips).dropna().unique()
si_zipcodes_array = pd.Series(si_zips).dropna().unique()

##
# Out:
# 11218
# 11206
# 11206
# 11224
# 11224
# 11207
# 11207
# 11208
# 11208
# 11215
# 11215
# 11223
# 11223
# 11229
# 11229
# 11203
# 11203
# 11231
# 11231
# 11209
# 11209
# 11234
# 11234
# 11215
# 11215
# 11209
# 11209
# 11236
# 11236
# 11235
# 11235
# 11209
# 11209
# 11237
# 11237
# 11238
# 11238
# 11215
# 11215
# 11221
# 11221
# 11238
# 11238
# 11223
# 11223
# 11237
# 11237
# 11210
# 11210
# 11233
# 11233
# 11219
# 11219
# 11226
# 11226
# 11208
# 11208
# 11231
# 11231
# 11213
# 11213
# 11221
# 11221
# 11234
# 11234
# 11234
# 11234
# 11220
# 11220
# 11204
# 11204
# 11213
# 11213
# 11212
# 11212
# 11206
# 11206
# 11225
# 11225
# 11220
# 11220
# 11234
# 11234
# 11231
# 11231
# 11210
# 11210
# 11216
# 11216
# 11229
# 11229
# 11233
# 11233
# 11214
# 11214
# 11212
# 11212
# 11216
# 11216
# nan
# nan
# 11204
# 11204
# 11228
# 11228
# 11229
# 11229
# 11203
# 11203
# 11210
# 11210
# 11206
# 11206
# 11212
# 11212
# 11209
# 11209
# 11209
# 11209
# 11226
# 11226
# 11249
# 11249
# 11213
# 11213
# ...

# %%
### functions that increment the occurences of top ten complaints in zip code.
### could be one larger function


def first_zip_top_complainers(): 
    complainers_obj = define_base_obj_to_use()
    for x in first_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] += 1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)



def second_zip_top_complainers():
    for x in second_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)


def third_zip_top_complainers():
    for x in third_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def fourth_zip_top_complainers():
    for x in fourth_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def fifth_zip_top_complainers():
    for x in fifth_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def six_zip_top_complainers():
    for x in six_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def seventh_zip_top_complainers():
    for x in seventh_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def eight_zip_top_complainers():
    for x in eigth_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def nine_zip_top_complainers():
    for x in nine_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def ten_zip_top_complainers():
    for x in tenth_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

# %%
#### variables storing values, to be using in data frames

one = first_zip_top_complainers()
two = second_zip_top_complainers()
three = third_zip_top_complainers()
four = fourth_zip_top_complainers()
five = fifth_zip_top_complainers()
six = six_zip_top_complainers()
seven = seventh_zip_top_complainers()
eight = eight_zip_top_complainers()
nine = nine_zip_top_complainers()
ten = ten_zip_top_complainers()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c1c6e2687e20> in <module>
#       2
#       3 one = first_zip_top_complainers()
# ----> 4 two = second_zip_top_complainers()
#       5 three = third_zip_top_complainers()
#       6 four = fourth_zip_top_complainers()
#
# <ipython-input-8-799b68dc2e7f> in second_zip_top_complainers()
#      20         if x not in complaints_tops_names:
#      21             pass
# ---> 22         elif (x in complainers_obj):
#      23             complainers_obj[x] +=1
#      24         else:
#
# NameError: name 'complainers_obj' is not defined

# %%
top_ten_pop_complaints_keys = top_ten_pop_complaints.keys()

# %%
### zip_code-complaints data frames


first_complainer_df = pd.DataFrame(  
     { "Zip": pop_zip_array[0],
     top_ten_pop_complaints_keys[0]: one[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: one[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: one[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: one[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: one[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: one[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: one[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: one[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: one[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: one[top_ten_pop_complaints_keys[9]],

 }, index={0}
)

second_complainer_df = pd.DataFrame(
     { "Zip": pop_zip_array[1],
     top_ten_pop_complaints_keys[0]: two[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: two[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: two[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: two[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: two[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: two[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: two[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: two[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: two[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: two[top_ten_pop_complaints_keys[9]],

 }, index={1}
)


third_complainer_df = pd.DataFrame(
     { "Zip": pop_zip_array[2],
     top_ten_pop_complaints_keys[0]: three[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: three[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: three[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: three[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: three[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: three[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: three[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: three[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: three[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: three[top_ten_pop_complaints_keys[9]],

 }, index={2}
)


fourth_complainer_df = pd.DataFrame(
     {"Zip": pop_zip_array[3],
     top_ten_pop_complaints_keys[0]: four[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: four[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: four[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: four[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: four[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: four[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: four[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: four[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: four[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: four[top_ten_pop_complaints_keys[9]],

 }, index={3}
)


fifth_complainer_df = pd.DataFrame(
     {"Zip": pop_zip_array[4],
     top_ten_pop_complaints_keys[0]: five[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: five[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: five[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: five[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: five[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: five[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: five[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: five[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: five[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: five[top_ten_pop_complaints_keys[9]],

 }, index={4}
)


sixth_complainer_df = pd.DataFrame(
     {"Zip": pop_zip_array[5],
     top_ten_pop_complaints_keys[0]: six[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: six[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: six[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: six[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: six[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: six[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: six[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: six[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: six[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: six[top_ten_pop_complaints_keys[9]],

 }, index={5}
)

seventh_complainer_df = pd.DataFrame(
     {"Zip": pop_zip_array[6],
     top_ten_pop_complaints_keys[0]: seven[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: seven[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: seven[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: seven[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: seven[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: seven[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: seven[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: seven[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: seven[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: seven[top_ten_pop_complaints_keys[9]],

 }, index={6}
)

eighth_complainer_df = pd.DataFrame(
     {
     "Zip": pop_zip_array[7],
     top_ten_pop_complaints_keys[0]: eight[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: eight[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: eight[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: eight[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: eight[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: eight[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: eight[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: eight[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: eight[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: eight[top_ten_pop_complaints_keys[9]],

 }, index={7}
)

nineth_complainer_df = pd.DataFrame(
     {"Zip": pop_zip_array[8],
     top_ten_pop_complaints_keys[0]: nine[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: nine[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: nine[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: nine[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: nine[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: nine[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: nine[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: nine[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: nine[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: nine[top_ten_pop_complaints_keys[9]],
     "Zip": pop_zip_array[8]
 }, index={8}
)

tenth_complainer_df = pd.DataFrame(
     {'Zip': pop_zip_array[9],
     top_ten_pop_complaints_keys[0]: ten[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: ten[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: ten[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: ten[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: ten[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: ten[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: ten[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: ten[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: ten[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: ten[top_ten_pop_complaints_keys[9]],
 }, index={9}
)

# %%
zipcodes_with_top_complaints = first_complainer_df.append([second_complainer_df, third_complainer_df, fourth_complainer_df, fifth_complainer_df, sixth_complainer_df, seventh_complainer_df, eighth_complainer_df, nineth_complainer_df, tenth_complainer_df])

# %%
zipcodes_with_top_complaints

# %%
### could be one function. wanted to separate based on previous variables and ease. would have to be stored in dictionary otherwise

def bronx_complainers(): 
    borough_complainers_dict = define_base_obj_to_use
    for complaint in bronx_complaints:  
        if complaint not in complaints_tops_names:
            pass
        elif (complaint in borough_complainers_dict and complaint in complaints_tops_names):
            borough_complainers_dict[complaint] +=1
        else:
            borough_complainers_dict[complaint] = 1
    return(borough_complainers_dict)

def queens_complainers(): 
    borough_complainers_dict = define_base_obj_to_use
    for complaint in queens_complaints: 
        if complaint not in complaints_tops_names:
            pass
        elif (complaint in borough_complainers_dict and complaint in complaints_tops_names):
            borough_complainers_dict[complaint] +=1
        else:
            borough_complainers_dict[complaint] = 1
    return(borough_complainers_dict)

def manhattan_complainers(): 
    borough_complainers_dict = define_base_obj_to_use
    for complaint in manhattan_complaints: 
        if complaint not in complaints_tops_names:
            pass
        elif (complaint in borough_complainers_dict and complaint in complaints_tops_names):
            borough_complainers_dict[complaint] +=1
        else:
            borough_complainers_dict[complaint] = 1
    return(borough_complainers_dict)

def si_complainers(): 
    borough_complainers_dict = define_base_obj_to_use
    for complaint in SI_complaints: 
        if complaint not in complaints_tops_names:
            pass
        elif (complaint in borough_complainers_dict and complaint in complaints_tops_names):
            borough_complainers_dict[complaint] +=1
        else:
            borough_complainers_dict[complaint] = 1
    return(borough_complainers_dict)

def brooklyn_complainers(): 
    borough_complainers_dict = define_base_obj_to_use
    for complaint in brooklyn_complaints: 
        if complaint not in complaints_tops_names:
            pass
        elif (complaint in borough_complainers_dict and complaint in complaints_tops_names):
            borough_complainers_dict[complaint] +=1
        else:
            borough_complainers_dict[complaint] = 1
    return(borough_complainers_dict)

# %%
bronx_complainers_var = bronx_complainers()
queens_complainers_var = queens_complainers()
manhattan_complainers_var = manhattan_complainers()
si_complainers_var = si_complainers()
brooklyn_complainers_var = brooklyn_complainers()

# %%
### dataframes for boroughs complaint totals

bronx_complainer_df = pd.DataFrame(
     {'Borough': boroughs_array[0],
     top_ten_pop_complaints_keys[0]: bronx_complainers_var[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: bronx_complainers_var[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: bronx_complainers_var[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: bronx_complainers_var[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: bronx_complainers_var[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: bronx_complainers_var[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: bronx_complainers_var[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: bronx_complainers_var[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: bronx_complainers_var[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: bronx_complainers_var[top_ten_pop_complaints_keys[9]],
 }, index={0}
)

 brooklyn_complainer_df = pd.DataFrame(
     {'Borough': boroughs_array[1],
     top_ten_pop_complaints_keys[0]: brooklyn_complainers_var[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: brooklyn_complainers_var[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: brooklyn_complainers_var[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: brooklyn_complainers_var[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: brooklyn_complainers_var[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: brooklyn_complainers_var[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: brooklyn_complainers_var[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: brooklyn_complainers_var[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: brooklyn_complainers_var[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: brooklyn_complainers_var[top_ten_pop_complaints_keys[9]],
 }, index={1}
)

 manhattan_complainer_df = pd.DataFrame(
     {'Borough': boroughs_array[2],
     top_ten_pop_complaints_keys[0]: manhattan_complainers_var[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: manhattan_complainers_var[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: manhattan_complainers_var[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: manhattan_complainers_var[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: manhattan_complainers_var[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: manhattan_complainers_var[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: manhattan_complainers_var[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: manhattan_complainers_var[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: manhattan_complainers_var[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: manhattan_complainers_var[top_ten_pop_complaints_keys[9]],
 }, index={2}
)

 queens_complainer_df = pd.DataFrame(
     {'Borough': boroughs_array[3],
     top_ten_pop_complaints_keys[0]: queens_complainers_var[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: queens_complainers_var[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: queens_complainers_var[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: queens_complainers_var[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: queens_complainers_var[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: queens_complainers_var[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: queens_complainers_var[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: queens_complainers_var[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: queens_complainers_var[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: queens_complainers_var[top_ten_pop_complaints_keys[9]],
 }, index={3}
)

 staten_island_complainer_df = pd.DataFrame(
     {'Borough': boroughs_array[4],
     top_ten_pop_complaints_keys[0]: si_complainers_var[top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: si_complainers_var[top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: si_complainers_var[top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: si_complainers_var[top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: si_complainers_var[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: si_complainers_var[top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: si_complainers_var[top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: si_complainers_var[top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: si_complainers_var[top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: si_complainers_var[top_ten_pop_complaints_keys[9]],
 }, index={4}
)
    
    
borough_with_complaints = bronx_complainer_df.append([brooklyn_complainer_df, manhattan_complainer_df, queens_complainer_df, staten_island_complainer_df])

# %%
borough_with_complaints

# %%
# complainer- index

# %%
### function to define population of each borough 
# function split into five for simplicity as opposed to a larger one


def count_brooklyn_people():
    zip_code_population_dictionary = zipcodes_population_obj()
    borough_counter = 0
    for x in brooklyn_zipcodes_array:
        safe_num = take_in_zip_code_spit_out_population(x)
        borough_counter += safe_num
    return(borough_counter)
    


def count_queens_people():
    zip_code_population_dictionary = zipcodes_population_obj()
    borough_counter = 0 
    for x in queens_zipcodes_array:
        safe_num = take_in_zip_code_spit_out_population(x)
        borough_counter += safe_num
    return(borough_counter)



def count_bronx_people():
    zip_code_population_dictionary = zipcodes_population_obj()
    borough_counter = 0
    for x in bronx_zipcodes_array:
        safe_num = take_in_zip_code_spit_out_population(x)
        borough_counter += safe_num
    return(borough_counter) 


def count_manhattan_people():
    zip_code_population_dictionary = zipcodes_population_obj()
    borough_counter = 0
    for x in manhattan_zipcodes_array:
        safe_num = take_in_zip_code_spit_out_population(x)
        borough_counter += safe_num
    return(borough_counter) 


def count_si_people():
    zip_code_population_dictionary = zipcodes_population_obj()
    borough_counter = 0
    for x in si_zipcodes_array:
        safe_num = take_in_zip_code_spit_out_population(x)
        borough_counter += safe_num
    return(borough_counter)

# %%
## variables for population count

si_people = count_si_people()
manhattan_people = count_manhattan_people()
brooklyn_people = count_brooklyn_people()
bronx_people = count_bronx_people()
queens_people = count_queens_people()
total_complaints_borough = city_data_file_read.groupby("Borough").size().to_dict()

# %%
population_obj ={
    "BROOKLYN": brooklyn_people,
    "QUEENS": queens_people,
    "BRONX": bronx_people,
    "STATEN ISLAND": si_people,
    "MANHATTAN": manhattan_people
}


population_df = pd.DataFrame(
    {
        "BROOKLYN" : population_obj['BROOKLYN'],
        "QUEENS": population_obj['QUEENS'],
        "BRONX": population_obj['BRONX'],
        "STATEN ISLAND": population_obj['STATEN ISLAND'],
        "MANHATTAN": population_obj['MANHATTAN'],
    }, index={0}
)

# %%
### dataframes with the borough population numbers and index


complainer_totals = {
    'BROOKLYN': int(total_complaints_borough['BROOKLYN']),
    'QUEENS': int(total_complaints_borough['QUEENS']),
    'BRONX': int(total_complaints_borough['BRONX']),
    'STATEN ISLAND': int(total_complaints_borough['STATEN ISLAND']),
    'MANHATTAN': int(total_complaints_borough['MANHATTAN'])    
}

brooklyn_populace = pd.DataFrame( ## brooklyn 
    {
        "Borough": "BROOKLYN",
        "Complainer Totals": complainer_totals["BROOKLYN"], 
        "Population": brooklyn_people, 
        "Complainer-Index": complainer_totals["BROOKLYN"]/int(brooklyn_people)
    }, index={0}
)


queens_populace = pd.DataFrame( ## queens 
    {
        "Borough": "QUEENS",
        "Complainer Totals": complainer_totals["QUEENS"], 
        "Population": queens_people, 
        "Complainer-Index": complainer_totals["QUEENS"]/int(queens_people)
        
        
    }, index={1}
)

bronx_populace = pd.DataFrame( ## bronx 
    {
        "Borough": "BRONX",
        "Complainer Totals": complainer_totals["BRONX"], 
        "Population": bronx_people, 
        "Complainer-Index": complainer_totals["BRONX"]/int(bronx_people)
        
    }, index={2}
)

si_populace = pd.DataFrame( ## staten island 
    {
        "Borough": "STATEN ISLAND",
        "Complainer Totals": complainer_totals["STATEN ISLAND"], 
        "Population": si_people,
        "Complainer-Index": complainer_totals["STATEN ISLAND"]/int(si_people)
        
    }, index={3}
)

manhattan_populace = pd.DataFrame( ## staten island 
    {
        "Borough": "MANHATTAN",
        "Complainer Totals": total_complaints_borough["MANHATTAN"], 
        "Population": manhattan_people, 
        "Complainer-Index": complainer_totals["MANHATTAN"]/int(manhattan_people)
        
    }, index={4}
)
all_boroughs = brooklyn_populace.append([queens_populace, bronx_populace, si_populace, manhattan_populace])

# %%
#### Organized Data
### All three tables laid out

# %%
# Complaints-Index 

all_boroughs

# %%
# Complaints by Zip Code
zipcodes_with_top_complaints

# %%
# Complaints by Borough

borough_with_complaints

# %%
# Things still to be addressed (unspecified). 


# Could have refactored the zipcode/borough functions into smaller more specific functions

# Following up from the outline 
# Did Not Address issue of unspecificed boroughs. I would probably look at a relationship between cities and zipcodes and see if they can be borrowed.
# their rows cannot be cleaned fully. It would skew the remaining data to elimate the complaints that they reported.
