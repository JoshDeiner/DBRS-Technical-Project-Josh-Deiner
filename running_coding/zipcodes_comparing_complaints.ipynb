# %%
# complainer- index

import pandas as pd
import numpy as np
import csv

import import_ipynb
import Actions
from Actions import define_base_obj_to_use

# %%
# from Actions import main_data_dataframe, pop_zip_array # maybe don't need to be recreated this way
from Actions import main_data_dataframe
from Actions import pop_zip_array
from Actions import zip_files_df
from Actions import boroughs_array
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-fa4d4109e42a> in <module>
#       5 from Actions import zip_files_df
#       6 from Actions import boroughs_array
# ----> 7 from Actions import nyc_complainers
#
# ImportError: cannot import name 'nyc_complainers' from 'Actions' (Actions.ipynb)

# %%
popular_complaints = pd.Series(main_data_dataframe.groupby('Complaint Type').size().sort_values(ascending=False))
top_ten_pop_complaints = pd.Series(popular_complaints[:10])

# %%
def define_zipcode_tables(): 
    obj = {}
    for x in range(10): 
        obj[x] = main_data_dataframe.loc[main_data_dataframe.Zip == pop_zip_array[x]]
        # obj[pop_zip_array[x]] = main_data_dataframe.loc[main_data_dataframe.Zip == float(pop_zip_array[x])]
    return obj

# %%
######## fix and make one
complaints_tops_names = top_ten_pop_complaints.keys()


def first_zip_top_complainers():  #****#
    first_zip_complaints = define_zipcode_tables()[0]["Complaint Type"]
    complainers_obj = define_base_obj_to_use()
    for x in first_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] += 1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)



def second_zip_top_complainers():
    second_zip_complaints = define_zipcode_tables()[1]["Complaint Type"]
    complainers_obj = define_base_obj_to_use()
    for x in second_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)


def third_zip_top_complainers():
    third_zip_complaints = define_zipcode_tables()[2]["Complaint Type"]
    complainers_obj = define_base_obj_to_use()
    for x in third_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def fourth_zip_top_complainers():
    fourth_zip_complaints = define_zipcode_tables()[3]["Complaint Type"]
    
    complainers_obj = define_base_obj_to_use()
    for x in fourth_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def fifth_zip_top_complainers():
    fifth_zip_complaints = define_zipcode_tables()[4]["Complaint Type"]
    complainers_obj = define_base_obj_to_use()
    for x in fifth_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def six_zip_top_complainers():
    six_zip_complaints = define_zipcode_tables()[5]["Complaint Type"]
    
    complainers_obj = define_base_obj_to_use()
    for x in six_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def seventh_zip_top_complainers():
    seventh_zip_complaints = define_zipcode_tables()[6]["Complaint Type"]
    complainers_obj = define_base_obj_to_use()
    for x in seventh_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def eight_zip_top_complainers():
    eigth_zip_complaints = define_zipcode_tables()[7]["Complaint Type"]
    complainers_obj = define_base_obj_to_use()
    for x in eigth_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def nine_zip_top_complainers():
    nine_zip_complaints = define_zipcode_tables()[8]["Complaint Type"]
    complainers_obj = define_base_obj_to_use()
    for x in nine_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

def ten_zip_top_complainers():
    tenth_zip_complaints = define_zipcode_tables()[9]["Complaint Type"]
    complainers_obj = define_base_obj_to_use()
    for x in tenth_zip_complaints:
        if x not in complaints_tops_names:
            pass
        elif (x in complainers_obj):
            complainers_obj[x] +=1
        else:
            complainers_obj[x] = 1
    return(complainers_obj)

# %%
### zip_code-complaints data frames

first_complainer_df = pd.DataFrame(  #### map
     { "Zip": pop_zip_array[0],
     complaints_tops_names[0]: first_zip_top_complainers()[complaints_tops_names[0]],
     complaints_tops_names[1]: first_zip_top_complainers()[complaints_tops_names[1]],
     complaints_tops_names[2]: first_zip_top_complainers()[complaints_tops_names[2]],
     complaints_tops_names[3]: first_zip_top_complainers()[complaints_tops_names[3]],
     complaints_tops_names[4]: first_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[5]: first_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[6]: first_zip_top_complainers()[complaints_tops_names[6]],
     complaints_tops_names[7]: first_zip_top_complainers()[complaints_tops_names[7]],
     complaints_tops_names[8]: first_zip_top_complainers()[complaints_tops_names[8]],
     complaints_tops_names[9]: first_zip_top_complainers()[complaints_tops_names[9]],

 }, index={0}
)

second_complainer_df = pd.DataFrame(
     { "Zip": pop_zip_array[1],
     complaints_tops_names[0]: second_zip_top_complainers()[complaints_tops_names[0]],
     complaints_tops_names[1]: second_zip_top_complainers()[complaints_tops_names[1]],
     complaints_tops_names[2]: second_zip_top_complainers()[complaints_tops_names[2]],
     complaints_tops_names[3]: second_zip_top_complainers()[complaints_tops_names[3]],
     complaints_tops_names[4]: second_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[5]: second_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[6]: second_zip_top_complainers()[complaints_tops_names[6]],
     complaints_tops_names[7]: second_zip_top_complainers()[complaints_tops_names[7]],
     complaints_tops_names[8]: second_zip_top_complainers()[complaints_tops_names[8]],
     complaints_tops_names[9]: second_zip_top_complainers()[complaints_tops_names[9]],

 }, index={1}
)


third_complainer_df = pd.DataFrame(
     { "Zip": pop_zip_array[2],
     complaints_tops_names[0]: third_zip_top_complainers()[complaints_tops_names[0]],
     complaints_tops_names[1]: third_zip_top_complainers()[complaints_tops_names[1]],
     complaints_tops_names[2]: third_zip_top_complainers()[complaints_tops_names[2]],
     complaints_tops_names[3]: third_zip_top_complainers()[complaints_tops_names[3]],
     complaints_tops_names[4]: third_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[5]: third_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[6]: third_zip_top_complainers()[complaints_tops_names[6]],
     complaints_tops_names[7]: third_zip_top_complainers()[complaints_tops_names[7]],
     complaints_tops_names[8]: third_zip_top_complainers()[complaints_tops_names[8]],
     complaints_tops_names[9]: third_zip_top_complainers()[complaints_tops_names[9]],

 }, index={2}
)


fourth_complainer_df = pd.DataFrame(
     {"Zip": pop_zip_array[3],
     complaints_tops_names[0]: fourth_zip_top_complainers()[complaints_tops_names[0]],
     complaints_tops_names[1]: fourth_zip_top_complainers()[complaints_tops_names[1]],
     complaints_tops_names[2]: fourth_zip_top_complainers()[complaints_tops_names[2]],
     complaints_tops_names[3]: fourth_zip_top_complainers()[complaints_tops_names[3]],
     complaints_tops_names[4]: fourth_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[5]: fourth_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[6]: fourth_zip_top_complainers()[complaints_tops_names[6]],
     complaints_tops_names[7]: fourth_zip_top_complainers()[complaints_tops_names[7]],
     complaints_tops_names[8]: fourth_zip_top_complainers()[complaints_tops_names[8]],
     complaints_tops_names[9]: fourth_zip_top_complainers()[complaints_tops_names[9]],

 }, index={3}
)


fifth_complainer_df = pd.DataFrame(
     {"Zip": pop_zip_array[4],
     complaints_tops_names[0]: fifth_zip_top_complainers()[complaints_tops_names[0]],
     complaints_tops_names[1]: fifth_zip_top_complainers()[complaints_tops_names[1]],
     complaints_tops_names[2]: fifth_zip_top_complainers()[complaints_tops_names[2]],
     complaints_tops_names[3]: fifth_zip_top_complainers()[complaints_tops_names[3]],
     complaints_tops_names[4]: fifth_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[5]: fifth_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[6]: fifth_zip_top_complainers()[complaints_tops_names[6]],
     complaints_tops_names[7]: fifth_zip_top_complainers()[complaints_tops_names[7]],
     complaints_tops_names[8]: fifth_zip_top_complainers()[complaints_tops_names[8]],
     complaints_tops_names[9]: fifth_zip_top_complainers()[complaints_tops_names[9]],

 }, index={4}
)


sixth_complainer_df = pd.DataFrame(
     {"Zip": pop_zip_array[5],
     complaints_tops_names[0]: six_zip_top_complainers()[complaints_tops_names[0]],
     complaints_tops_names[1]: six_zip_top_complainers()[complaints_tops_names[1]],
     complaints_tops_names[2]: six_zip_top_complainers()[complaints_tops_names[2]],
     complaints_tops_names[3]: six_zip_top_complainers()[complaints_tops_names[3]],
     complaints_tops_names[4]: six_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[5]: six_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[6]: six_zip_top_complainers()[complaints_tops_names[6]],
     complaints_tops_names[7]: six_zip_top_complainers()[complaints_tops_names[7]],
     complaints_tops_names[8]: six_zip_top_complainers()[complaints_tops_names[8]],
     complaints_tops_names[9]: six_zip_top_complainers()[complaints_tops_names[9]],

 }, index={5}
)

seventh_complainer_df = pd.DataFrame(
     {"Zip": pop_zip_array[6],
     complaints_tops_names[0]: seventh_zip_top_complainers()[complaints_tops_names[0]],
     complaints_tops_names[1]: seventh_zip_top_complainers()[complaints_tops_names[1]],
     complaints_tops_names[2]: seventh_zip_top_complainers()[complaints_tops_names[2]],
     complaints_tops_names[3]: seventh_zip_top_complainers()[complaints_tops_names[3]],
     complaints_tops_names[4]: seventh_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[5]: seventh_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[6]: seventh_zip_top_complainers()[complaints_tops_names[6]],
     complaints_tops_names[7]: seventh_zip_top_complainers()[complaints_tops_names[7]],
     complaints_tops_names[8]: seventh_zip_top_complainers()[complaints_tops_names[8]],
     complaints_tops_names[9]: seventh_zip_top_complainers()[complaints_tops_names[9]],

 }, index={6}
)

eighth_complainer_df = pd.DataFrame(
     {
     "Zip": pop_zip_array[7],
     complaints_tops_names[0]: eight_zip_top_complainers()[complaints_tops_names[0]],
     complaints_tops_names[1]: eight_zip_top_complainers()[complaints_tops_names[1]],
     complaints_tops_names[2]: eight_zip_top_complainers()[complaints_tops_names[2]],
     complaints_tops_names[3]: eight_zip_top_complainers()[complaints_tops_names[3]],
     complaints_tops_names[4]: eight_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[5]: eight_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[6]: eight_zip_top_complainers()[complaints_tops_names[6]],
     complaints_tops_names[7]: eight_zip_top_complainers()[complaints_tops_names[7]],
     complaints_tops_names[8]: eight_zip_top_complainers()[complaints_tops_names[8]],
     complaints_tops_names[9]: eight_zip_top_complainers()[complaints_tops_names[9]],

 }, index={7}
)

nineth_complainer_df = pd.DataFrame(
     {"Zip": pop_zip_array[8],
     complaints_tops_names[0]: nine_zip_top_complainers()[complaints_tops_names[0]],
     complaints_tops_names[1]: nine_zip_top_complainers()[complaints_tops_names[1]],
     complaints_tops_names[2]: nine_zip_top_complainers()[complaints_tops_names[2]],
     complaints_tops_names[3]: nine_zip_top_complainers()[complaints_tops_names[3]],
     complaints_tops_names[4]: nine_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[5]: nine_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[6]: nine_zip_top_complainers()[complaints_tops_names[6]],
     complaints_tops_names[7]: nine_zip_top_complainers()[complaints_tops_names[7]],
     complaints_tops_names[8]: nine_zip_top_complainers()[complaints_tops_names[8]],
     complaints_tops_names[9]: nine_zip_top_complainers()[complaints_tops_names[9]],
     "Zip": pop_zip_array[8]
 }, index={8}
)

tenth_complainer_df = pd.DataFrame(
     {'Zip': pop_zip_array[9],
     complaints_tops_names[0]: ten_zip_top_complainers()[complaints_tops_names[0]],
     complaints_tops_names[1]: ten_zip_top_complainers()[complaints_tops_names[1]],
     complaints_tops_names[2]: ten_zip_top_complainers()[complaints_tops_names[2]],
     complaints_tops_names[3]: ten_zip_top_complainers()[complaints_tops_names[3]],
     complaints_tops_names[4]: ten_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[5]: ten_zip_top_complainers()[complaints_tops_names[4]],
     complaints_tops_names[6]: ten_zip_top_complainers()[complaints_tops_names[6]],
     complaints_tops_names[7]: ten_zip_top_complainers()[complaints_tops_names[7]],
     complaints_tops_names[8]: ten_zip_top_complainers()[complaints_tops_names[8]],
     complaints_tops_names[9]: ten_zip_top_complainers()[complaints_tops_names[9]],
 }, index={9}
)

# %%
zipcodes_with_top_complaints = first_complainer_df.append([second_complainer_df, third_complainer_df, fourth_complainer_df, fifth_complainer_df, sixth_complainer_df, seventh_complainer_df, eighth_complainer_df, nineth_complainer_df, tenth_complainer_df])

# %%
zipcodes_with_top_complaints
