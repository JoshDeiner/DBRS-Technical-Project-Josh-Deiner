# %%
import pandas as pd
import numpy as np


import import_ipynb
import Actions
# %run Actions.ipynb

from Actions import main_data_dataframe
from Actions import define_base_obj_to_use
from Actions import define_boroughs_tables

from Actions import boroughs_array

# %%
bronxtable = define_boroughs_tables()[4]  #### to remove post docker 
manhattan_table = define_boroughs_tables()[2]
queens_table = define_boroughs_tables()[1]
staten_island_table = define_boroughs_tables()[3]
brooklyn_table = define_boroughs_tables()[0]

# %%
# helper variables

popular_complaints = pd.Series(main_data_dataframe.groupby('Complaint Type').size().sort_values(ascending=False))
top_ten_pop_complaints = pd.Series(popular_complaints[:10])
top_ten_pop_complaints_keys = top_ten_pop_complaints.keys()
complaints_tops_names = top_ten_pop_complaints.keys()
sorted_boroughs_by_boroughs = define_boroughs_tables()[0].append([define_boroughs_tables()[1], define_boroughs_tables()[2], define_boroughs_tables()[3], define_boroughs_tables()[4]])

# %%
def create_borough_complaints_obj():
    empty_complaints_obj = define_base_obj_to_use()
    obj = {}
    for x in boroughs_array:
        obj[x] = empty_complaints_obj
    return obj

# %%
def nyc_complainers(): ### just tweak and build off this
    borough_obj = {'BRONX': {}, 'QUEENS': {}, 'MANHATTAN' : {}, 'STATEN ISLAND': {}, 'BROOKLYN': {} }
    bronx_complainers_dict = create_borough_complaints_obj()['BRONX']
    

    for complaint in define_boroughs_tables()[4]["Complaint Type"]:  
        if complaint not in complaints_tops_names:
            pass
        elif (complaint in bronx_complainers_dict and complaint in complaints_tops_names):
            bronx_complainers_dict[complaint] +=1
        else:
            bronx_complainers_dict[complaint] = 1
    
    queens_complainers_dict = create_borough_complaints_obj()['QUEENS']
    for complaint in define_boroughs_tables()[1]["Complaint Type"]: 
        if complaint not in complaints_tops_names:
            pass
        elif (complaint in queens_complainers_dict and complaint in complaints_tops_names):
            queens_complainers_dict[complaint] +=1
        else:
            queens_complainers_dict[complaint] = 1

    manhattan_complainers_dict = create_borough_complaints_obj()['MANHATTAN']
    for complaint in define_boroughs_tables()[2]["Complaint Type"]: 
        if complaint not in complaints_tops_names:
            pass
        elif (complaint in manhattan_complainers_dict and complaint in complaints_tops_names):
            manhattan_complainers_dict[complaint] +=1
        else:
            manhattan_complainers_dict[complaint] = 1

    si_complainers_dict = create_borough_complaints_obj()['STATEN ISLAND']
    for complaint in define_boroughs_tables()[3]["Complaint Type"]: 
        if complaint not in complaints_tops_names:
            pass
        elif (complaint in si_complainers_dict and complaint in complaints_tops_names):
            si_complainers_dict[complaint] +=1
        else:
            si_complainers_dict[complaint] = 1

    brooklyn_complainers_dict = create_borough_complaints_obj()['BROOKLYN']
    for complaint in define_boroughs_tables()[0]["Complaint Type"]: 
        if complaint not in complaints_tops_names:
            pass
        elif (complaint in brooklyn_complainers_dict and complaint in complaints_tops_names):
            brooklyn_complainers_dict[complaint] +=1
        else:
            brooklyn_complainers_dict[complaint] = 1
            
    borough_obj['BRONX'] = bronx_complainers_dict
    borough_obj['BROOKLYN'] = brooklyn_complainers_dict
    borough_obj['STATEN ISLAND'] = si_complainers_dict
    borough_obj['QUEENS'] = queens_complainers_dict
    borough_obj['MANHATTAN'] = manhattan_complainers_dict
    return borough_obj

# %%
bronx_complainer_df = pd.DataFrame(
     {'Borough': boroughs_array[0],
     top_ten_pop_complaints_keys[0]: nyc_complainers()['BRONX'][top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: nyc_complainers()['BRONX'][top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: nyc_complainers()['BRONX'][top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: nyc_complainers()['BRONX'][top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: nyc_complainers()['BRONX'][top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: nyc_complainers()['BRONX'][top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: nyc_complainers()['BRONX'][top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: nyc_complainers()['BRONX'][top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: nyc_complainers()['BRONX'][top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: nyc_complainers()['BRONX'][top_ten_pop_complaints_keys[9]],
 }, index={0}
)

brooklyn_complainer_df = pd.DataFrame(

     {'Borough': boroughs_array[1],
     top_ten_pop_complaints_keys[0]: nyc_complainers()['BROOKLYN'][top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: nyc_complainers()['BROOKLYN'][top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: nyc_complainers()['BROOKLYN'][top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: nyc_complainers()['BROOKLYN'][top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: nyc_complainers()['BROOKLYN'][top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: nyc_complainers()['BROOKLYN'][top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: nyc_complainers()['BROOKLYN'][top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: nyc_complainers()['BROOKLYN'][top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: nyc_complainers()['BROOKLYN'][top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: nyc_complainers()['BROOKLYN'][top_ten_pop_complaints_keys[9]],
 }, index={1}
)

manhattan_complainer_df = pd.DataFrame(
     {'Borough': boroughs_array[2],
     top_ten_pop_complaints_keys[0]: nyc_complainers()['MANHATTAN'][top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: nyc_complainers()['MANHATTAN'][top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: nyc_complainers()['MANHATTAN'][top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: nyc_complainers()['MANHATTAN'][top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: nyc_complainers()['MANHATTAN'][top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: nyc_complainers()['MANHATTAN'][top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: nyc_complainers()['MANHATTAN'][top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: nyc_complainers()['MANHATTAN'][top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: nyc_complainers()['MANHATTAN'][top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: nyc_complainers()['MANHATTAN'][top_ten_pop_complaints_keys[9]],
 }, index={2}
)

queens_complainer_df = pd.DataFrame(
     {'Borough': boroughs_array[3],
     top_ten_pop_complaints_keys[0]: nyc_complainers()['QUEENS'][top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: nyc_complainers()['QUEENS'][top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: nyc_complainers()['QUEENS'][top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: nyc_complainers()['QUEENS'][top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: nyc_complainers()['QUEENS'][top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: nyc_complainers()['QUEENS'][top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: nyc_complainers()['QUEENS'][top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: nyc_complainers()['QUEENS'][top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: nyc_complainers()['QUEENS'][top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: nyc_complainers()['QUEENS'][top_ten_pop_complaints_keys[9]],
 }, index={3}
)

staten_island_complainer_df = pd.DataFrame(
     {'Borough': boroughs_array[4],
     top_ten_pop_complaints_keys[0]: nyc_complainers()['STATEN ISLAND'][top_ten_pop_complaints_keys[0]],
     top_ten_pop_complaints_keys[1]: nyc_complainers()['STATEN ISLAND'][top_ten_pop_complaints_keys[1]],
     top_ten_pop_complaints_keys[2]: nyc_complainers()['STATEN ISLAND'][top_ten_pop_complaints_keys[2]],
     top_ten_pop_complaints_keys[3]: nyc_complainers()['STATEN ISLAND'][top_ten_pop_complaints_keys[3]],
     top_ten_pop_complaints_keys[4]: nyc_complainers()['STATEN ISLAND'][top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[5]: nyc_complainers()['STATEN ISLAND'][top_ten_pop_complaints_keys[4]],
     top_ten_pop_complaints_keys[6]: nyc_complainers()['STATEN ISLAND'][top_ten_pop_complaints_keys[6]],
     top_ten_pop_complaints_keys[7]: nyc_complainers()['STATEN ISLAND'][top_ten_pop_complaints_keys[7]],
     top_ten_pop_complaints_keys[8]: nyc_complainers()['STATEN ISLAND'][top_ten_pop_complaints_keys[8]],
     top_ten_pop_complaints_keys[9]: nyc_complainers()['STATEN ISLAND'][top_ten_pop_complaints_keys[9]],
 }, index={4}
)

# %%
borough_with_complaints = bronx_complainer_df.append([brooklyn_complainer_df, manhattan_complainer_df, queens_complainer_df, staten_island_complainer_df])

# %%
borough_with_complaints
# Out:
#          Borough  Request Large Bulky Item Collection  UNSANITARY CONDITION  \
# 0       BROOKLYN                                  326                  1319
# 1         QUEENS                                 2099                  1315
# 2      MANHATTAN                                  108                   723
# 3  STATEN ISLAND                                 2129                   487
# 4          BRONX                                  109                    73
#
#    Noise  PAINT/PLASTER  PLUMBING  Street Condition  DOOR/WINDOW  \
# 0    110            955       723               723          541
# 1    787            686       758               758          649
# 2   1059            650       471               471          252
# 3    538            216       433               433          108
# 4    146             73        37                37            0
#
#    HEAT/HOT WATER  Street Light Condition  Illegal Parking
# ...
