# %%
# Manahttan check for totals
import pandas as pd
from sodapy import Socrata

newDictionary = {} # oveerall complaints, sets dictionary.
#
otherdict = {}
api = pd.read_json('https://data.cityofnewyork.us/resource/fhrw-4uyv.json', orient='columns')
# client = Socrata("'https://data.cityofnewyork.us/resource/fhrw-4uyv.json", "LOQNQRhAyAV9gvAB7w7JFdIa8")
# results = client.get("https://data.cityofnewyork.us/resource/fhrw-4uyv.json", limit=2000)
complaints = api['complaint_type']
for x in complaints:
    if x in newDictionary:
        newDictionary[x]+=1
    else:
        newDictionary[x] = 1

print(newDictionary)


for x in newDictionary:
    print(x, newDictionary[x])

    newA = 'https://data.cityofnewyork.us/resource/fhrw-4uyv.json'
apii = pd.read_json(newA, orient='columns')
apii["complaint_type"]

newDictionary = {} # oveerall complaints, sets dictionary
otherdict = {}
for x in apii["complaint_type"]:
    if x in newDictionary:
        newDictionary[x]+=1
    else:
        newDictionary[x] = 1


for x in newDictionary: # print all borrough complaints
    print(x)


Boroughcomplaints = ''
listboroughcomplaints = []
for x in newDictionary:
    listboroughcomplaints.insert(0,x)
#     print(x,otherdict[x])
# print(listboroughcomplaints)
# listboroughcomplaints.append(10)
iterator= 0
while iterator < 10:
    iterator +=1
    print(listboroughcomplaints[iterator])


#value of top ten complaint, not accounting for year for bronx
value = 0
for x in newDictionary:
#     print(newDictionary[x])
    value += newDictionary[x]
    print(value)


apii['incident_zip'] # run condition for where a a zip code is in the array of zip codes. need to b matching on year. need to be mar
# Out:
# {'Request Large Bulky Item Collection': 72, 'Noise - Residential': 337, 'Food Poisoning': 4, 'Highway Condition': 2, 'Noise - Commercial': 77, 'Illegal Parking': 116, 'Noise - Street/Sidewalk': 35, 'Blocked Driveway': 120, 'DCA / DOH New License Application Request': 1, 'Street Condition': 19, 'Noise - Vehicle': 17, 'Rodent': 15, 'Bridge Condition': 1, 'Traffic': 3, 'Traffic Signal Condition': 17, 'Food Establishment': 11, 'Smoking': 5, 'Drinking': 1, 'Street Sign - Missing': 1, 'Street Sign - Damaged': 2, 'Electronics Waste': 12, 'Taxi Complaint': 8, 'Noise': 17, 'Derelict Vehicle': 16, 'Water System': 9, 'Sidewalk Condition': 4, 'Consumer Complaint': 7, 'For Hire Vehicle Complaint': 11, 'Noise - House of Worship': 1, 'New Tree Request': 6, 'Street Light Condition': 12, 'Non-Emergency Police Matter': 1, 'Question': 1, 'Benefit Card Replacement': 4, 'Sewer': 6, 'Ferry Inquiry': 1, 'Animal Abuse': 1, 'Unsanitary Animal Pvt Property': 1, 'Air Quality': 2, 'Damaged Tree': 2, 'Maintenance or Facility': 1, 'Indoor Sewage': 1, 'HPD Literature Request': 1, 'Curb Condition': 1, 'Lead': 2, 'Ferry Complaint': 1, 'Public Payphone Complaint': 1, 'Graffiti': 5, 'Housing - Low Income Senior': 1, 'Urinating in Public': 1, 'General Construction/Plumbing': 3, 'Special Projects Inspection Team (SPIT)': 1, 'Building/Use': 2, 'Boilers': 1}
# Request Large Bulky Item Collection 72
# Noise - Residential 337
# Food Poisoning 4
# Highway Condition 2
# Noise - Commercial 77
# Illegal Parking 116
# Noise - Street/Sidewalk 35
# Blocked Driveway 120
# DCA / DOH New License Application Request 1
# Street Condition 19
# Noise - Vehicle 17
# Rodent 15
# Bridge Condition 1
# Traffic 3
# Traffic Signal Condition 17
# Food Establishment 11
# Smoking 5
# Drinking 1
# Street Sign - Missing 1
# Street Sign - Damaged 2
# Electronics Waste 12
# Taxi Complaint 8
# Noise 17
# Derelict Vehicle 16
# Water System 9
# Sidewalk Condition 4
# Consumer Complaint 7
# For Hire Vehicle Complaint 11
# Noise - House of Worship 1
# New Tree Request 6
# Street Light Condition 12
# Non-Emergency Police Matter 1
# Question 1
# Benefit Card Replacement 4
# Sewer 6
# Ferry Inquiry 1
# Animal Abuse 1
# Unsanitary Animal Pvt Property 1
# Air Quality 2
# Damaged Tree 2
# Maintenance or Facility 1
# Indoor Sewage 1
# HPD Literature Request 1
# Curb Condition 1
# Lead 2
# Ferry Complaint 1
# Public Payphone Complaint 1
# Graffiti 5
# Housing - Low Income Senior 1
# Urinating in Public 1
# General Construction/Plumbing 3
# Special Projects Inspection Team (SPIT) 1
# Building/Use 2
# Boilers 1
# Request Large Bulky Item Collection
# Noise - Residential
# Food Poisoning
# Highway Condition
# Noise - Commercial
# Illegal Parking
# Noise - Street/Sidewalk
# Blocked Driveway
# DCA / DOH New License Application Request
# Street Condition
# Noise - Vehicle
# Rodent
# Bridge Condition
# Traffic
# Traffic Signal Condition
# Food Establishment
# Smoking
# Drinking
# Street Sign - Missing
# Street Sign - Damaged
# Electronics Waste
# Taxi Complaint
# Noise
# Derelict Vehicle
# Water System
# Sidewalk Condition
# Consumer Complaint
# For Hire Vehicle Complaint
# Noise - House of Worship
# New Tree Request
# Street Light Condition
# Non-Emergency Police Matter
# Question
# Benefit Card Replacement
# Sewer
# Ferry Inquiry
# Animal Abuse
# Unsanitary Animal Pvt Property
# Air Quality
# Damaged Tree
# Maintenance or Facility
# Indoor Sewage
# HPD Literature Request
# Curb Condition
# Lead
# Ferry Complaint
# Public Payphone Complaint
# Graffiti
# Housing - Low Income Senior
# Urinating in Public
# General Construction/Plumbing
# Special Projects Inspection Team (SPIT)
# Building/Use
# Boilers
# Building/Use
# Special Projects Inspection Team (SPIT)
# General Construction/Plumbing
# Urinating in Public
# Housing - Low Income Senior
# Graffiti
# Public Payphone Complaint
# Ferry Complaint
# Lead
# Curb Condition
# 72
# 409
# 413
# 415
# 492
# 608
# 643
# 763
# 764
# 783
# 800
# 815
# 816
# 819
# 836
# 847
# 852
# 853
# 854
# 856
# 868
# 876
# 893
# 909
# 918
# 922
# 929
# 940
# 941
# 947
# 959
# 960
# 961
# 965
# 971
# 972
# 973
# 974
# 976
# 978
# 979
# 980
# 981
# 982
# 984
# 985
# 986
# 991
# 992
# 993
# 996
# 997
# 999
# 1000
# 0      11233.0
# 1      10009.0
# 2      11226.0
# 3      10468.0
# 4      10474.0
# 5      11220.0
# 6      10012.0
# 7          NaN
# 8      10003.0
# 9      11203.0
# 10     11233.0
# 11     10468.0
# 12     10003.0
# 13     11418.0
# 14     10453.0
# 15     11222.0
# 16     11228.0
# 17     11205.0
# 18     11201.0
# 19         NaN
# 20     10013.0
# 21     11224.0
# 22     10301.0
# 23     11219.0
# 24     10467.0
# 25     11205.0
# 26     11229.0
# 27     10467.0
# 28     11385.0
# 29     10467.0
#         ...
# 970    11221.0
# 971    11372.0
# 972    10314.0
# 973    11234.0
# 974    10023.0
# 975    11358.0
# 976    10016.0
# 977    10304.0
# 978    10468.0
# 979    11419.0
# 980    11221.0
# 981        NaN
# 982    11435.0
# 983    10463.0
# 984    11215.0
# 985    11416.0
# 986        NaN
# 987    10469.0
# 988    11215.0
# 989    11204.0
# 990    11236.0
# 991    11436.0
# 992    11201.0
# 993    11204.0
# 994    11236.0
# 995        NaN
# 996    10306.0
# 997        NaN
# 998    10458.0
# 999    10040.0
# Name: incident_zip, Length: 1000, dtype: float64
